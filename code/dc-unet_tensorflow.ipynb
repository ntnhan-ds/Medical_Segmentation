# %% [markdown]
# # **Medical Image Segmentation Using DC-UNet**

# %% [markdown]
# ### **Import libraries & datasets**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import cv2
import os
from PIL import Image
import albumentations as A
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, UpSampling2D ,concatenate, BatchNormalization, Activation, Add,add,LeakyReLU
from tensorflow.keras.models import load_model
from PIL import Image
from skimage.metrics import structural_similarity as ssim
from sklearn.metrics import jaccard_score
import warnings
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.5 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
# Config
class Config:
    img_size=(256,256)
    batch_size=4
    epochs=10
    learning_rate=1e-4

config=Config()

# %%
# Read and sorting data
name_data_image_path_kvasirseg="./data/kvasir-seg/Kvasir-SEG/images"
name_data_mask_path_kvasirseg="./data/kvasir-seg/Kvasir-SEG/masks"
name_data_image_path_clinicdb="./data/cvc-clinicdb/CVC-ClinicDB/images"
name_data_mask_path_clinicdb="./data/cvc-clinicdb/CVC-ClinicDB/masks"
name_data_image_path_colondb="./data/cvc-colondb/CVC-ColonDB/images"
name_data_mask_path_colondb="./data/cvc-colondb/CVC-ColonDB/masks"

data_image_kvasirseg=sorted(os.listdir(name_data_image_path_kvasirseg))
data_mask_kvasirseg=sorted(os.listdir(name_data_mask_path_kvasirseg))
data_image_clinicdb=sorted(os.listdir(name_data_image_path_clinicdb))
data_mask_clinicdb=sorted(os.listdir(name_data_mask_path_clinicdb))
data_image_colondb=sorted(os.listdir(name_data_image_path_colondb))
data_mask_colondb=sorted(os.listdir(name_data_mask_path_colondb))

# %%
print("Image path kvasir-seg data: ",data_image_kvasirseg[:3],data_mask_kvasirseg[:3])
print("Image path clinicdb data: ",data_image_clinicdb[:3],data_mask_clinicdb[:3])
print("Image path colondb data: ",data_image_colondb[:3],data_mask_colondb[:3])
# Out:
# Image path kvasir-seg data:  ['cju0qkwl35piu0993l0dewei2.jpg', 'cju0qoxqj9q6s0835b43399p4.jpg', 'cju0qx73cjw570799j4n5cjze.jpg'] ['cju0qkwl35piu0993l0dewei2.jpg', 'cju0qoxqj9q6s0835b43399p4.jpg', 'cju0qx73cjw570799j4n5cjze.jpg']
# Image path clinicdb data:  ['1.png', '10.png', '100.png'] ['1.png', '10.png', '100.png']
# Image path colondb data:  ['1.png', '10.png', '100.png'] ['1.png', '10.png', '100.png']

# %%
# Concat data
data_images_combined = (
    [os.path.join(name_data_image_path_kvasirseg, img) for img in data_image_kvasirseg] +
    [os.path.join(name_data_image_path_clinicdb, img) for img in data_image_clinicdb] +
    [os.path.join(name_data_image_path_colondb, img) for img in data_image_colondb]
)

data_masks_combined = (
    [os.path.join(name_data_mask_path_kvasirseg, mask) for mask in data_mask_kvasirseg] +
    [os.path.join(name_data_mask_path_clinicdb, mask) for mask in data_mask_clinicdb] +
    [os.path.join(name_data_mask_path_colondb, mask) for mask in data_mask_colondb]
)
len(data_images_combined),len(data_masks_combined)
# Out:
# (1992, 1992)

# %% [markdown]
# ### **Process and prepare data**

# %%
def split_data_train_valid_test(images_data,masks_data):
    paired_list_data=list(zip(images_data,masks_data))
    np.random.shuffle(paired_list_data)
    data_img,data_mask=zip(*paired_list_data)

    train_images_list,temp_images_list,train_masks_list,temp_masks_list = train_test_split(data_img,data_mask,test_size=0.2,random_state=42)
    val_images_list,test_images_list,val_masks_list,test_masks_list=train_test_split(temp_images_list,temp_masks_list,test_size=0.5,random_state=42)

    return (
        train_images_list,train_masks_list,
        val_images_list,val_masks_list,
        test_images_list,test_masks_list,
    )

# %%
train_images_list,train_masks_list,val_images_list,val_masks_list,test_images_list,test_masks_list=split_data_train_valid_test(data_images_combined,data_masks_combined)
len(train_images_list),len(train_masks_list),len(val_images_list),len(val_masks_list),len(test_images_list),len(test_masks_list)
# Out:
# (1593, 1593, 199, 199, 200, 200)

# %%
# Transform
train_transform = A.Compose([
    A.Resize(*config.img_size),
    A.Rotate(limit=15, p=0.2), 
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(p=0.2),  
    A.Normalize(mean=(0,0,0), std=(1,1,1), max_pixel_value=255)
])

val_transform=A.Compose([
    A.Resize(*config.img_size),
    A.Normalize(mean=(0,0,0),std=(1,1,1),max_pixel_value=255)
])

# %%
# Initalizedd class Dataset
class Dataset(keras.utils.Sequence):
    def __init__(self, img_list, mask_list, transform, batch_size=4):
        self.img_list = img_list  # Full path
        self.mask_list = mask_list
        self.transform = transform
        self.batch_size = batch_size

    def __len__(self):
        return int(np.ceil(len(self.img_list) / self.batch_size))
        
    def __getitem__(self, index):
        batch_img_paths = self.img_list[index * self.batch_size : (index + 1) * self.batch_size]
        batch_mask_paths = self.mask_list[index * self.batch_size : (index + 1) * self.batch_size]

        images, masks = [], []
        for img_path, mask_path in zip(batch_img_paths, batch_mask_paths):
            img = Image.open(img_path).convert("RGB")  
            mask = Image.open(mask_path).convert("L")

            mask = np.array(mask) / 255.0
            mask[mask > 0.5] = 1

            augmented = self.transform(image=np.array(img), mask=mask)
            images.append(augmented["image"])
            masks.append(np.expand_dims(augmented["mask"], axis=-1))

        return np.array(images), np.array(masks)

# %%
train_dataset = Dataset(train_images_list, train_masks_list, train_transform)
valid_dataset = Dataset(val_images_list, val_masks_list, train_transform)
test_dataset = Dataset(test_images_list, test_masks_list, val_transform)

# %% [markdown]
# #### **Initialize Dual channel Unet model**

# %%
def conv2d_bn(x, filters, kernel_size, padding='same', strides=(1, 1), activation='relu'):
    x = Conv2D(filters, kernel_size, strides=strides, padding=padding, use_bias=False)(x)
    x = BatchNormalization(axis=3, scale=False)(x)
    if activation:
        if activation == 'leaky_relu':
            x = LeakyReLU(alpha=0.01)(x)  
        else:
            x = Activation(activation)(x) 
    return x

def DCBlock(U, inp, alpha=1.67):
    W = alpha * U

    conv3x3_1 = conv2d_bn(inp, int(W * 0.167), (3, 3))
    conv5x5_1 = conv2d_bn(conv3x3_1, int(W * 0.333), (3, 3))
    conv7x7_1 = conv2d_bn(conv5x5_1, int(W * 0.5), (3, 3))
    out1 = concatenate([conv3x3_1, conv5x5_1, conv7x7_1])

    conv3x3_2 = conv2d_bn(inp, int(W * 0.167), (3, 3))
    conv5x5_2 = conv2d_bn(conv3x3_2, int(W * 0.333), (3, 3))
    conv7x7_2 = conv2d_bn(conv5x5_2, int(W * 0.5), (3, 3))
    out2 = concatenate([conv3x3_2, conv5x5_2, conv7x7_2])

    out = Add()([out1, out2])
    out = Activation('relu')(out)
    out = BatchNormalization()(out)

    return out

def ResPath(filters, length, inp):
    shortcut = conv2d_bn(inp, filters, (1, 1), activation=None)
    out = conv2d_bn(inp, filters, (3, 3))
    out = Add()([shortcut, out])
    out = Activation('relu')(out)
    out = BatchNormalization(axis=3, scale=False)(out)

    for _ in range(length - 1):
        shortcut = conv2d_bn(out, filters, (1, 1), activation=None)
        out = conv2d_bn(out, filters, (3, 3))
        out = Add()([shortcut, out])
        out = Activation('relu')(out)
        out = BatchNormalization(axis=3, scale=False)(out)

    return out

def DCUNet(height, width, channels):
    inputs = Input((height, width, channels))
    # Downsampling path
    dcblock1 = DCBlock(32, inputs)
    pool1 = MaxPooling2D((2, 2))(dcblock1)
    dcblock1 = ResPath(32, 4, dcblock1)

    dcblock2 = DCBlock(64, pool1)
    pool2 = MaxPooling2D((2, 2))(dcblock2)
    dcblock2 = ResPath(64, 3, dcblock2)

    dcblock3 = DCBlock(128, pool2)
    pool3 = MaxPooling2D((2, 2))(dcblock3)
    dcblock3 = ResPath(128, 2, dcblock3)

    dcblock4 = DCBlock(256, pool3)
    pool4 = MaxPooling2D((2, 2))(dcblock4)
    dcblock4 = ResPath(256, 1, dcblock4)

    dcblock5 = DCBlock(512, pool4)

    # Upsampling path
    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(dcblock5), dcblock4])
    dcblock6 = DCBlock(256, up6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(dcblock6), dcblock3])
    dcblock7 = DCBlock(128, up7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(dcblock7), dcblock2])
    dcblock8 = DCBlock(64, up8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(dcblock8), dcblock1])
    dcblock9 = DCBlock(32, up9)

    outputs = conv2d_bn(dcblock9, 1, (1, 1), activation='sigmoid')

    return Model(inputs, outputs, name="DC-UNet")

dc_model = DCUNet(256, 256, 3)
dc_model.summary()
# Out:
# Model: "DC-UNet"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 256, 256, 8)    │            216 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 256, 256, 8)    │            216 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 256, 256, 8)    │             24 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 256, 256, 8)    │             24 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 256, 256, 8)    │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_3 (Activation) │ (None, 256, 256, 8)    │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 256, 256, 17)   │          1,224 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 256, 256, 17)   │          1,224 │ activation_3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 256, 256, 17)   │             51 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 256, 256, 17)   │             51 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 256, 256, 17)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_4 (Activation) │ (None, 256, 256, 17)   │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 256, 256, 26)   │          3,978 │ activation_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 256, 256, 26)   │          3,978 │ activation_4[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 256, 256, 26)   │             78 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 256, 256, 26)   │             78 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 256, 256, 26)   │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_5 (Activation) │ (None, 256, 256, 26)   │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 256, 256, 51)   │              0 │ activation[0][0],      │
# │                           │                        │                │ activation_1[0][0],    │
# │                           │                        │                │ activation_2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 256, 256, 51)   │              0 │ activation_3[0][0],    │
# │ (Concatenate)             │                        │                │ activation_4[0][0],    │
# │                           │                        │                │ activation_5[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 256, 256, 51)   │              0 │ concatenate[0][0],     │
# │                           │                        │                │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_6 (Activation) │ (None, 256, 256, 51)   │              0 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 256, 256, 51)   │            204 │ activation_6[0][0]     │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 128, 128, 51)   │              0 │ batch_normalization_6… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 128, 128, 17)   │          7,803 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 128, 128, 17)   │          7,803 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_19    │ (None, 128, 128, 17)   │             51 │ conv2d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_22    │ (None, 128, 128, 17)   │             51 │ conv2d_17[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_15             │ (None, 128, 128, 17)   │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_18             │ (None, 128, 128, 17)   │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 128, 128, 35)   │          5,355 │ activation_15[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 128, 128, 35)   │          5,355 │ activation_18[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_20    │ (None, 128, 128, 35)   │            105 │ conv2d_15[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_23    │ (None, 128, 128, 35)   │            105 │ conv2d_18[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_16             │ (None, 128, 128, 35)   │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_19             │ (None, 128, 128, 35)   │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 128, 128, 53)   │         16,695 │ activation_16[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_19 (Conv2D)        │ (None, 128, 128, 53)   │         16,695 │ activation_19[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_21    │ (None, 128, 128, 53)   │            159 │ conv2d_16[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_24    │ (None, 128, 128, 53)   │            159 │ conv2d_19[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_17             │ (None,
0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_18            │ (None, 128, 128, 105)  │              0 │ activation_72[0][0],   │
# │ (Concatenate)             │                        │                │ activation_73[0][0],   │
# │                           │                        │                │ activation_74[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 256, 256, 32)   │          1,024 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 256, 256, 32)   │             96 │ conv2d_13[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_17 (Add)              │ (None, 128, 128, 105)  │              0 │ concatenate_17[0][0],  │
# │                           │                        │                │ concatenate_18[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 256, 256, 32)   │             96 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_13             │ (None, 256, 256, 32)   │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_75             │ (None, 128, 128, 105)  │              0 │ add_17[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 256, 256, 32)   │              0 │ batch_normalization_1… │
# │                           │                        │                │ activation_13[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_85    │ (None, 128, 128, 105)  │            420 │ activation_75[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_14             │ (None, 256, 256, 32)   │              0 │ add_4[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 256, 256, 32)   │         13,472 │ batch_normalization_8… │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_18    │ (None, 256, 256, 32)   │             96 │ activation_14[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_19            │ (None, 256, 256, 64)   │              0 │ conv2d_transpose_3[0]… │
# │ (Concatenate)             │                        │                │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_68 (Conv2D)        │ (None, 256, 256, 8)    │          4,608 │ concatenate_19[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_71 (Conv2D)        │ (None, 256, 256, 8)    │          4,608 │ concatenate_19[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_86    │ (None, 256, 256, 8)    │             24 │ conv2d_68[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_89    │ (None, 256, 256, 8)    │             24 │ conv2d_71[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_76             │ (None, 256, 256, 8)    │              0 │ batch_normalization_8… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_79             │ (None, 256, 256, 8)    │              0 │ batch_normalization_8… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_69 (Conv2D)        │ (None, 256, 256, 17)   │          1,224 │ activation_76[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_72 (Conv2D)        │ (None, 256, 256, 17)   │          1,224 │ activation_79[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_87    │ (None, 256, 256, 17)   │             51 │ conv2d_69[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_90    │ (None, 256, 256, 17)   │             51 │ conv2d_72[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_77             │ (None, 256, 256, 17)   │              0 │ batch_normalization_8… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_80             │ (None, 256, 256, 17)   │              0 │ batch_normalization_9… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_70 (Conv2D)        │ (None, 256, 256, 26)   │          3,978 │ activation_77[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_73 (Conv2D)        │ (None, 256, 256, 26)   │          3,978 │ activation_80[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_88    │ (None, 256, 256, 26)   │             78 │ conv2d_70[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_91    │ (None, 256, 256, 26)   │             78 │ conv2d_73[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_78             │ (None, 256, 256, 26)   │              0 │ batch_normalization_8… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_81             │ (None, 256, 256, 26)   │              0 │ batch_normalization_9… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_20            │ (None, 256, 256, 51)   │              0 │ activation_76[0][0],   │
# │ (Concatenate)             │                        │                │ activation_77[0][0],   │
# │                           │                        │                │ activation_78[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_21            │ (None, 256, 256, 51)   │              0 │ activation_79[0][0],   │
# │ (Concatenate)             │                        │                │ activation_80[0][0],   │
# │                           │                        │                │ activation_81[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_18 (Add)              │ (None, 256, 256, 51)   │              0 │ concatenate_20[0][0],  │
# │                           │                        │                │ concatenate_21[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_82             │ (None, 256, 256, 51)   │              0 │ add_18[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_92    │ (None, 256, 256, 51)   │            204 │ activation_82[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_74 (Conv2D)        │ (None, 256, 256, 1)    │             51 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_93    │ (None, 256, 256, 1)    │              3 │ conv2d_74[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_83             │ (None, 256, 256, 1)    │              0 │ batch_normalization_9… │
# │ (Activation)              │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 10,049,568 (38.34 MB)
#  Trainable params: 10,029,928 (38.26 MB)
#  Non-trainable params: 19,640 (76.72 KB)

# %% [markdown]
# ### **Training model**

# %%
dc_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=config.learning_rate),
    loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),  
    metrics=[tf.keras.metrics.BinaryCrossentropy(from_logits=False)]  
)

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "best_dc-unet_model.keras",  
    monitor="val_loss",
    save_best_only=True,
    mode="min",
    verbose=1,
    save_weights_only=False 
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss", 
    patience=10, 
    restore_best_weights=True
)

history = dc_model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=150,
    callbacks=[early_stopping, checkpoint],
    verbose=1
)
# Out:
# Epoch 1/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.6810 - loss: 0.6810
# Epoch 1: val_loss improved from inf to 0.65537, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 143s 147ms/step - binary_crossentropy: 0.6809 - loss: 0.6809 - val_binary_crossentropy: 0.6554 - val_loss: 0.6554
# Epoch 2/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.6048 - loss: 0.6048
# Epoch 2: val_loss improved from 0.65537 to 0.58150, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 131ms/step - binary_crossentropy: 0.6048 - loss: 0.6048 - val_binary_crossentropy: 0.5815 - val_loss: 0.5815
# Epoch 3/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.5761 - loss: 0.5761
# Epoch 3: val_loss improved from 0.58150 to 0.55138, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 131ms/step - binary_crossentropy: 0.5760 - loss: 0.5760 - val_binary_crossentropy: 0.5514 - val_loss: 0.5514
# Epoch 4/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.5465 - loss: 0.5465
# Epoch 4: val_loss improved from 0.55138 to 0.51029, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 131ms/step - binary_crossentropy: 0.5465 - loss: 0.5465 - val_binary_crossentropy: 0.5103 - val_loss: 0.5103
# Epoch 5/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.5196 - loss: 0.5196
# Epoch 5: val_loss improved from 0.51029 to 0.48216, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 132ms/step - binary_crossentropy: 0.5196 - loss: 0.5196 - val_binary_crossentropy: 0.4822 - val_loss: 0.4822
# Epoch 6/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - binary_crossentropy: 0.4968 - loss: 0.4968
# Epoch 6: val_loss improved from 0.48216 to 0.48214, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 132ms/step - binary_crossentropy: 0.4968 - loss: 0.4968 - val_binary_crossentropy: 0.4821 - val_loss: 0.4821
# Epoch 7/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.4739 - loss: 0.4739
# Epoch 7: val_loss improved from 0.48214 to 0.45670, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - binary_crossentropy: 0.4739 - loss: 0.4739 - val_binary_crossentropy: 0.4567 - val_loss: 0.4567
# Epoch 8/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.4516 - loss: 0.4516
# Epoch 8: val_loss improved from 0.45670 to 0.44297, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 131ms/step - binary_crossentropy: 0.4516 - loss: 0.4516 - val_binary_crossentropy: 0.4430 - val_loss: 0.4430
# Epoch 9/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.4379 - loss: 0.4379
# Epoch 9: val_loss improved from 0.44297 to 0.42070, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 131ms/step - binary_crossentropy: 0.4379 - loss: 0.4379 - val_binary_crossentropy: 0.4207 - val_loss: 0.4207
# Epoch 10/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.4193 - loss: 0.4193
# Epoch 10: val_loss did not improve from 0.42070
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 58s 129ms/step - binary_crossentropy: 0.4193 - loss: 0.4193 - val_binary_crossentropy: 0.4272 - val_loss: 0.4272
# Epoch 11/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.4032 - loss: 0.4032
# Epoch 11: val_loss improved from 0.42070 to 0.40122, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 131ms/step - binary_crossentropy: 0.4032 - loss: 0.4032 - val_binary_crossentropy: 0.4012 - val_loss: 0.4012
# Epoch 12/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.3899 - loss: 0.3899
# Epoch 12: val_loss improved from 0.40122 to 0.38049, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - binary_crossentropy: 0.3899 - loss: 0.3899 - val_binary_crossentropy: 0.3805 - val_loss: 0.3805
# Epoch 13/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.3746 - loss: 0.3746
# Epoch 13: val_loss did not improve from 0.38049
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 58s 129ms/step - binary_crossentropy: 0.3746 - loss: 0.3746 - val_binary_crossentropy: 0.3846 - val_loss: 0.3846
# Epoch 14/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.3624 - loss: 0.3624
# Epoch 14: val_loss improved from 0.38049 to 0.35978, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 131ms/step - binary_crossentropy: 0.3624 - loss: 0.3624 - val_binary_crossentropy: 0.3598 - val_loss: 0.3598
# Epoch 15/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.3518 - loss: 0.3518
# Epoch 15: val_loss improved from 0.35978 to 0.35473, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - binary_crossentropy: 0.3518 - loss: 0.3518 - val_binary_crossentropy: 0.3547 - val_loss: 0.3547
# Epoch 16/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.3422 - loss: 0.3422
# Epoch 16: val_loss improved from 0.35473 to 0.34013, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - binary_crossentropy: 0.3422 - loss: 0.3422 - val_binary_crossentropy: 0.3401 - val_loss: 0.3401
# Epoch 17/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.3290 - loss: 0.3290
# Epoch 17: val_loss improved from 0.34013 to 0.33915, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - binary_crossentropy: 0.3290 - loss: 0.3290 - val_binary_crossentropy: 0.3392 - val_loss: 0.3392
# Epoch 18/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.3184 - loss: 0.3184
# Epoch 18: val_loss improved from 0.33915 to 0.32119, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - binary_crossentropy: 0.3184 - loss: 0.3184 - val_binary_crossentropy: 0.3212 - val_loss: 0.3212
# Epoch 19/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.3098 - loss: 0.3098
# Epoch 19: val_loss improved from 0.32119 to 0.30536, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 131ms/step - binary_crossentropy: 0.3098 - loss: 0.3098 - val_binary_crossentropy: 0.3054 - val_loss: 0.3054
# Epoch 20/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.2970 - loss: 0.2970
# Epoch 20: val_loss did not improve from 0.30536
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - binary_crossentropy: 0.2970 - loss: 0.2970 - val_binary_crossentropy: 0.3149 - val_loss: 0.3149
# Epoch 21/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.2881 - loss: 0.2881
# Epoch 21: val_loss did not improve from 0.30536
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.2881 - loss: 0.2881 - val_binary_crossentropy: 0.3054 - val_loss: 0.3054
# Epoch 22/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.2773 - loss: 0.2773
# Epoch 22: val_loss improved from 0.30536 to 0.29039, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - binary_crossentropy: 0.2773 - loss: 0.2773 - val_binary_crossentropy: 0.2904 - val_loss: 0.2904
# Epoch 23/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.2741 - loss: 0.2741
# Epoch 23: val_loss did not improve from 0.29039
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.2741 - loss: 0.2741 - val_binary_crossentropy: 0.2920 - val_loss: 0.2920
# Epoch 24/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.2662 - loss: 0.2662
# Epoch 24: val_loss improved from 0.29039 to 0.28692, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - binary_crossentropy: 0.2662 - loss: 0.2662 - val_binary_crossentropy: 0.2869 - val_loss: 0.2869
# Epoch 25/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.2585 - loss: 0.2585
# Epoch 25: val_loss improved from 0.28692 to 0.27929, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - binary_crossentropy: 0.2585 - loss: 0.2585 - val_binary_crossentropy: 0.2793 - val_loss: 0.2793
# Epoch 26/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.2525 - loss: 0.2525
# Epoch 26: val_loss improved from 0.27929 to 0.26727, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - binary_crossentropy: 0.2525 - loss: 0.2525 - val_binary_crossentropy: 0.2673 - val_loss: 0.2673
# Epoch 27/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.2421 - loss: 0.2421
# Epoch 27: val_loss improved from 0.26727 to 0.26219, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - binary_crossentropy: 0.2421 - loss: 0.2421 - val_binary_crossentropy: 0.2622 - val_loss: 0.2622
# Epoch 28/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.2377 - loss: 0.2377
# Epoch 28: val_loss did not improve from 0.26219
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.2377 - loss: 0.2377 - val_binary_crossentropy: 0.2677 - val_loss: 0.2677
# Epoch 29/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.2328 - loss: 0.2328
# Epoch 29: val_loss improved from 0.26219 to 0.24534, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - binary_crossentropy: 0.2328 - loss: 0.2328 - val_binary_crossentropy: 0.2453 - val_loss: 0.2453
# Epoch 30/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.2282 - loss: 0.2282
# Epoch 30: val_loss improved from 0.24534 to 0.23701, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - binary_crossentropy: 0.2282 - loss: 0.2282 - val_binary_crossentropy: 0.2370 - val_loss: 0.2370
# Epoch 31/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.2199 - loss: 0.2199
# Epoch 31: val_loss improved from 0.23701 to 0.23456, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - binary_crossentropy: 0.2199 - loss: 0.2199 - val_binary_crossentropy: 0.2346 - val_loss: 0.2346
# Epoch 32/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.2116 - loss: 0.2116
# Epoch 32: val_loss improved from 0.23456 to 0.22847, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - binary_crossentropy: 0.2116 - loss: 0.2116 - val_binary_crossentropy: 0.2285 - val_loss: 0.2285
# Epoch 33/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.2090 - loss: 0.2090
# Epoch 33: val_loss improved from 0.22847 to 0.22115, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - binary_crossentropy: 0.2090 - loss: 0.2090 - val_binary_crossentropy: 0.2212 - val_loss: 0.2212
# Epoch 34/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.2047 - loss: 0.2047
# Epoch 34: val_loss did not improve from 0.22115
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 128ms/step - binary_crossentropy: 0.2047 - loss: 0.2047 - val_binary_crossentropy: 0.2237 - val_loss: 0.2237
# Epoch 35/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.1987 - loss: 0.1987
# Epoch 35: val_loss improved from 0.22115 to 0.21340, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 131ms/step - binary_crossentropy: 0.1987 - loss: 0.1987 - val_binary_crossentropy: 0.2134 - val_loss: 0.2134
# Epoch 36/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.1951 - loss: 0.1951
# Epoch 36: val_loss improved from 0.21340 to 0.21237, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - binary_crossentropy: 0.1951 - loss: 0.1951 - val_binary_crossentropy: 0.2124 - val_loss: 0.2124
# Epoch 37/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.1886 - loss: 0.1886
# Epoch 37: val_loss improved from 0.21237 to 0.21150, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 131ms/step - binary_crossentropy: 0.1887 - loss: 0.1887 - val_binary_crossentropy: 0.2115 - val_loss: 0.2115
# Epoch 38/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.1876 - loss: 0.1876
# Epoch 38: val_loss improved from 0.21150 to 0.20608, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - binary_crossentropy: 0.1876 - loss: 0.1876 - val_binary_crossentropy: 0.2061 - val_loss: 0.2061
# Epoch 39/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1849 - loss: 0.1849
# Epoch 39: val_loss improved from 0.20608 to 0.20081, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 58s 130ms/step - binary_crossentropy: 0.1849 - loss: 0.1849 - val_binary_crossentropy: 0.2008 - val_loss: 0.2008
# Epoch 40/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.1844 - loss: 0.1844
# Epoch 40: val_loss improved from 0.20081 to 0.19311, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 131ms/step - binary_crossentropy: 0.1844 - loss: 0.1844 - val_binary_crossentropy: 0.1931 - val_loss: 0.1931
# Epoch 41/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.1755 - loss: 0.1755
# Epoch 41: val_loss did not improve from 0.19311
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - binary_crossentropy: 0.1755 - loss: 0.1755 - val_binary_crossentropy: 0.2093 - val_loss: 0.2093
# Epoch 42/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.1779 - loss: 0.1779
# Epoch 42: val_loss did not improve from 0.19311
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 128ms/step - binary_crossentropy: 0.1779 - loss: 0.1779 - val_binary_crossentropy: 0.1985 - val_loss: 0.1985
# Epoch 43/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1715 - loss: 0.1715
# Epoch 43: val_loss improved from 0.19311 to 0.18909, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 131ms/step - binary_crossentropy: 0.1715 - loss: 0.1715 - val_binary_crossentropy: 0.1891 - val_loss: 0.1891
# Epoch 44/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.1687 - loss: 0.1687
# Epoch 44: val_loss improved from 0.18909 to 0.18434, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - binary_crossentropy: 0.1687 - loss: 0.1687 - val_binary_crossentropy: 0.1843 - val_loss: 0.1843
# Epoch 45/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - binary_crossentropy: 0.1648 - loss: 0.1648
# Epoch 45: val_loss did not improve from 0.18434
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - binary_crossentropy: 0.1648 - loss: 0.1648 - val_binary_crossentropy: 0.1849 - val_loss: 0.1849
# Epoch 46/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1695 - loss: 0.1695
# Epoch 46: val_loss did not improve from 0.18434
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1695 - loss: 0.1695 - val_binary_crossentropy: 0.1937 - val_loss: 0.1937
# Epoch 47/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1625 - loss: 0.1625
# Epoch 47: val_loss improved from 0.18434 to 0.18117, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 58s 129ms/step - binary_crossentropy: 0.1625 - loss: 0.1625 - val_binary_crossentropy: 0.1812 - val_loss: 0.1812
# Epoch 48/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - binary_crossentropy: 0.1582 - loss: 0.1582
# Epoch 48: val_loss improved from 0.18117 to 0.17310, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 58s 129ms/step - binary_crossentropy: 0.1582 - loss: 0.1582 - val_binary_crossentropy: 0.1731 - val_loss: 0.1731
# Epoch 49/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - binary_crossentropy: 0.1652 - loss: 0.1652
# Epoch 49: val_loss did not improve from 0.17310
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - binary_crossentropy: 0.1652 - loss: 0.1652 - val_binary_crossentropy: 0.1770 - val_loss: 0.1770
# Epoch 50/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1586 - loss: 0.1586
# Epoch 50: val_loss did not improve from 0.17310
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - binary_crossentropy: 0.1586 - loss: 0.1586 - val_binary_crossentropy: 0.1732 - val_loss: 0.1732
# Epoch 51/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1598 - loss: 0.1598
# Epoch 51: val_loss improved from 0.17310 to 0.17233, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - binary_crossentropy: 0.1598 - loss: 0.1598 - val_binary_crossentropy: 0.1723 - val_loss: 0.1723
# Epoch 52/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1551 - loss: 0.1551
# Epoch 52: val_loss did not improve from 0.17233
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1551 - loss: 0.1551 - val_binary_crossentropy: 0.1796 - val_loss: 0.1796
# Epoch 53/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1562 - loss: 0.1562
# Epoch 53: val_loss improved from 0.17233 to 0.17101, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 58s 129ms/step - binary_crossentropy: 0.1562 - loss: 0.1562 - val_binary_crossentropy: 0.1710 - val_loss: 0.1710
# Epoch 54/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - binary_crossentropy: 0.1518 - loss: 0.1518
# Epoch 54: val_loss improved from 0.17101 to 0.16727, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 58s 129ms/step - binary_crossentropy: 0.1518 - loss: 0.1518 - val_binary_crossentropy: 0.1673 - val_loss: 0.1673
# Epoch 55/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1532 - loss: 0.1532
# Epoch 55: val_loss did not improve from 0.16727
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1532 - loss: 0.1532 - val_binary_crossentropy: 0.1676 - val_loss: 0.1676
# Epoch 56/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1518 - loss: 0.1518
# Epoch 56: val_loss did not improve from 0.16727
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1518 - loss: 0.1518 - val_binary_crossentropy: 0.1700 - val_loss: 0.1700
# Epoch 57/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1532 - loss: 0.1532
# Epoch 57: val_loss improved from 0.16727 to 0.16638, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 58s 129ms/step - binary_crossentropy: 0.1532 - loss: 0.1532 - val_binary_crossentropy: 0.1664 - val_loss: 0.1664
# Epoch 58/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - binary_crossentropy: 0.1489 - loss: 0.1489
# Epoch 58: val_loss improved from 0.16638 to 0.16518, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - binary_crossentropy: 0.1489 - loss: 0.1489 - val_binary_crossentropy: 0.1652 - val_loss: 0.1652
# Epoch 59/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1488 - loss: 0.1488
# Epoch 59: val_loss did not improve from 0.16518
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1488 - loss: 0.1488 - val_binary_crossentropy: 0.1653 - val_loss: 0.1653
# Epoch 60/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1488 - loss: 0.1488
# Epoch 60: val_loss did not improve from 0.16518
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1488 - loss: 0.1488 - val_binary_crossentropy: 0.1705 - val_loss: 0.1705
# Epoch 61/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1520 - loss: 0.1520
# Epoch 61: val_loss improved from 0.16518 to 0.15779, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 58s 129ms/step - binary_crossentropy: 0.1519 - loss: 0.1519 - val_binary_crossentropy: 0.1578 - val_loss: 0.1578
# Epoch 62/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1539 - loss: 0.1539
# Epoch 62: val_loss did not improve from 0.15779
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1539 - loss: 0.1539 - val_binary_crossentropy: 0.1667 - val_loss: 0.1667
# Epoch 63/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - binary_crossentropy: 0.1456 - loss: 0.1456
# Epoch 63: val_loss did not improve from 0.15779
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - binary_crossentropy: 0.1456 - loss: 0.1456 - val_binary_crossentropy: 0.1666 - val_loss: 0.1666
# Epoch 64/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - binary_crossentropy: 0.1452 - loss: 0.1452
# Epoch 64: val_loss improved from 0.15779 to 0.15603, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 58s 129ms/step - binary_crossentropy: 0.1453 - loss: 0.1453 - val_binary_crossentropy: 0.1560 - val_loss: 0.1560
# Epoch 65/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1518 - loss: 0.1518
# Epoch 65: val_loss did not improve from 0.15603
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1517 - loss: 0.1517 - val_binary_crossentropy: 0.1711 - val_loss: 0.1711
# Epoch 66/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - binary_crossentropy: 0.1451 - loss: 0.1451
# Epoch 66: val_loss did not improve from 0.15603
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - binary_crossentropy: 0.1452 - loss: 0.1452 - val_binary_crossentropy: 0.1639 - val_loss: 0.1639
# Epoch 67/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1475 - loss: 0.1475
# Epoch 67: val_loss did not improve from 0.15603
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1475 - loss: 0.1475 - val_binary_crossentropy: 0.1600 - val_loss: 0.1600
# Epoch 68/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1463 - loss: 0.1463
# Epoch 68: val_loss did not improve from 0.15603
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1463 - loss: 0.1463 - val_binary_crossentropy: 0.1615 - val_loss: 0.1615
# Epoch 69/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1454 - loss: 0.1454
# Epoch 69: val_loss did not improve from 0.15603
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1454 - loss: 0.1454 - val_binary_crossentropy: 0.1674 - val_loss: 0.1674
# Epoch 70/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1463 - loss: 0.1463
# Epoch 70: val_loss improved from 0.15603 to 0.15564, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 58s 129ms/step - binary_crossentropy: 0.1463 - loss: 0.1463 - val_binary_crossentropy: 0.1556 - val_loss: 0.1556
# Epoch 71/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1445 - loss: 0.1445
# Epoch 71: val_loss did not improve from 0.15564
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1446 - loss: 0.1446 - val_binary_crossentropy: 0.1723 - val_loss: 0.1723
# Epoch 72/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1490 - loss: 0.1490
# Epoch 72: val_loss did not improve from 0.15564
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1490 - loss: 0.1490 - val_binary_crossentropy: 0.1568 - val_loss: 0.1568
# Epoch 73/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - binary_crossentropy: 0.1431 - loss: 0.1431
# Epoch 73: val_loss improved from 0.15564 to 0.15506, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 58s 129ms/step - binary_crossentropy: 0.1431 - loss: 0.1431 - val_binary_crossentropy: 0.1551 - val_loss: 0.1551
# Epoch 74/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - binary_crossentropy: 0.1484 - loss: 0.1484
# Epoch 74: val_loss did not improve from 0.15506
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - binary_crossentropy: 0.1484 - loss: 0.1484 - val_binary_crossentropy: 0.1625 - val_loss: 0.1625
# Epoch 75/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1410 - loss: 0.1410
# Epoch 75: val_loss improved from 0.15506 to 0.15238, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 58s 129ms/step - binary_crossentropy: 0.1410 - loss: 0.1410 - val_binary_crossentropy: 0.1524 - val_loss: 0.1524
# Epoch 76/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1398 - loss: 0.1398
# Epoch 76: val_loss did not improve from 0.15238
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1398 - loss: 0.1398 - val_binary_crossentropy: 0.1602 - val_loss: 0.1602
# Epoch 77/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1475 - loss: 0.1475
# Epoch 77: val_loss did not improve from 0.15238
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1475 - loss: 0.1475 - val_binary_crossentropy: 0.1572 - val_loss: 0.1572
# Epoch 78/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1436 - loss: 0.1436
# Epoch 78: val_loss did not improve from 0.15238
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1436 - loss: 0.1436 - val_binary_crossentropy: 0.1678 - val_loss: 0.1678
# Epoch 79/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1438 - loss: 0.1438
# Epoch 79: val_loss did not improve from 0.15238
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1438 - loss: 0.1438 - val_binary_crossentropy: 0.1576 - val_loss: 0.1576
# Epoch 80/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1496 - loss: 0.1496
# Epoch 80: val_loss did not improve from 0.15238
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - binary_crossentropy: 0.1496 - loss: 0.1496 - val_binary_crossentropy: 0.1697 - val_loss: 0.1697
# Epoch 81/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1417 - loss: 0.1417
# Epoch 81: val_loss did not improve from 0.15238
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1417 - loss: 0.1417 - val_binary_crossentropy: 0.1598 - val_loss: 0.1598
# Epoch 82/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1418 - loss: 0.1418
# Epoch 82: val_loss did not improve from 0.15238
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1418 - loss: 0.1418 - val_binary_crossentropy: 0.1632 - val_loss: 0.1632
# Epoch 83/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1433 - loss: 0.1433
# Epoch 83: val_loss did not improve from 0.15238
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1433 - loss: 0.1433 - val_binary_crossentropy: 0.1596 - val_loss: 0.1596
# Epoch 84/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - binary_crossentropy: 0.1465 - loss: 0.1465
# Epoch 84: val_loss did not improve from 0.15238
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - binary_crossentropy: 0.1465 - loss: 0.1465 - val_binary_crossentropy: 0.1695 - val_loss: 0.1695
# Epoch 85/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1490 - loss: 0.1490
# Epoch 85: val_loss improved from 0.15238 to 0.15234, saving model to best_dc-unet_model.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 58s 129ms/step - binary_crossentropy: 0.1490 - loss: 0.1490 - val_binary_crossentropy: 0.1523 - val_loss: 0.1523
# Epoch 86/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1466 - loss: 0.1466
# Epoch 86: val_loss did not improve from 0.15234
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - binary_crossentropy: 0.1466 - loss: 0.1466 - val_binary_crossentropy: 0.1679 - val_loss: 0.1679
# Epoch 87/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1502 - loss: 0.1502
# Epoch 87: val_loss did not improve from 0.15234
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1502 - loss: 0.1502 - val_binary_crossentropy: 0.1709 - val_loss: 0.1709
# Epoch 88/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1422 - loss: 0.1422
# Epoch 88: val_loss did not improve from 0.15234
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1423 - loss: 0.1423 - val_binary_crossentropy: 0.1745 - val_loss: 0.1745
# Epoch 89/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1465 - loss: 0.1465
# Epoch 89: val_loss did not improve from 0.15234
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1465 - loss: 0.1465 - val_binary_crossentropy: 0.1567 - val_loss: 0.1567
# Epoch 90/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1451 - loss: 0.1451
# Epoch 90: val_loss did not improve from 0.15234
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1451 - loss: 0.1451 - val_binary_crossentropy: 0.1679 - val_loss: 0.1679
# Epoch 91/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1429 - loss: 0.1429
# Epoch 91: val_loss did not improve from 0.15234
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1430 - loss: 0.1430 - val_binary_crossentropy: 0.1756 - val_loss: 0.1756
# Epoch 92/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1460 - loss: 0.1460
# Epoch 92: val_loss did not improve from 0.15234
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - binary_crossentropy: 0.1460 - loss: 0.1460 - val_binary_crossentropy: 0.1680 - val_loss: 0.1680
# Epoch 93/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1434 - loss: 0.1434
# Epoch 93: val_loss did not improve from 0.15234
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1434 - loss: 0.1434 - val_binary_crossentropy: 0.1643 - val_loss: 0.1643
# Epoch 94/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1454 - loss: 0.1454
# Epoch 94: val_loss did not improve from 0.15234
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1454 - loss: 0.1454 - val_binary_crossentropy: 0.1597 - val_loss: 0.1597
# Epoch 95/150
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - binary_crossentropy: 0.1451 - loss: 0.1451
# Epoch 95: val_loss did not improve from 0.15234
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - binary_crossentropy: 0.1451 - loss: 0.1451 - val_binary_crossentropy: 0.1609 - val_loss: 0.1609

# %%
best_model = tf.keras.models.load_model("best_dc-unet_model.keras") # Load .keras and convert to .h5
best_model.save("best_dc-unet_model.h5", save_format="h5")
print("Best model save successfully!")

dc_model.save("dc-unet_model.h5")
print("Model final save successfully!")
# Out:
# Best model save successfully!
# Model final save successfully!

# %%
# Visualize
plt.plot(history.history["loss"], label="Train Loss", color="green")
plt.plot(history.history["val_loss"], label="Validation Loss", color="red")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# Pick random 
sample_index = 13
sample_img, sample_mask = test_dataset[sample_index]  


if len(sample_img.shape) == 4:  
    sample_img = sample_img[1]  
    sample_mask = sample_mask[1]

print(f"Image shape after fix: {sample_img.shape}") 

if sample_img.max() <= 1.0:  
    sample_img_display = (sample_img * 255).astype(np.uint8)  
else:
    sample_img_display = sample_img.astype(np.uint8) 


sample_img_input = np.expand_dims(sample_img, axis=0).astype(np.float32)  

pred_mask = best_model.predict(sample_img_input)[0]  
pred_mask = np.squeeze(pred_mask) 
pred_mask = (pred_mask > 0.5).astype(np.uint8)  

plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.imshow(sample_img_display)  
plt.title("Origin image")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(sample_mask.squeeze(), cmap="gray")  
plt.title("Real mask")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(pred_mask, cmap="gray")  
plt.title("Predicted mask")
plt.axis("off")

plt.show()
# Out:
# Image shape after fix: (256, 256, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
